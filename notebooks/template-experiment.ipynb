# %% [markdown]
# # Experiment Title\n
# \n
# Date: YYYY-MM-DD  \n
# Track: LLM | Quantum AI  \n
# Goal: One-sentence experiment objective

# %% [markdown]
# ## Setup

# %%
# Install/import dependencies here\n
# Example: !pip install qiskit pennylane jax\n

# %% [markdown]
# ## Data / Inputs

# %%
# Load or define data/input circuits here\n

# %% [markdown]
# ## Model / Circuit

# %%
# Define model or quantum circuit\n

# %% [markdown]
# ## Training / Execution

# %%
# Run training or simulation\n

# %% [markdown]
# ## Evaluation

# %%
# Metrics and plots\n

# %% [markdown]
# ## Conclusions and Next Steps\n
# - What worked\n
# - What failed\n
# - Next experiment
